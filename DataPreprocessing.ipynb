# %%
import numpy as np
import pandas as pd
import joblib
import os

# %%
# %run DataCleaning.ipynb
# %run DataNormalization.ipynb
# %run DataFeatureExtraction.ipynb
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1632\3476190814.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_1632\3476190814.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_1632\3476190814.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill", inplace=True)

# %%
final_df = featured_df
final_df.head(40)
# Out:
#              timestamp tunnel_id  methane_pct  temperature_c  humidity_pct  \
# 0  2025-03-01 10:00:00         A          0.8           28.0            65
# 3  2025-03-01 10:05:00         A          0.9           28.5            66
# 6  2025-03-01 10:10:00         A          1.0           29.0            66
# 9  2025-03-01 10:15:00         A          1.2           29.5            67
# 12 2025-03-01 10:20:00         A          1.4           30.0            68
# 15 2025-03-01 10:25:00         A          1.6           31.0            69
# 18 2025-03-01 10:30:00         A          1.8           32.0            70
# 21 2025-03-01 10:35:00         A          2.0           33.0            71
# 24 2025-03-01 10:40:00         A          2.2           34.0            72
# 27 2025-03-01 10:45:00         A          2.5           35.0            73
# 30 2025-03-01 10:50:00         A          2.5           36.0            74
# ...

# %%
os.makedirs("models", exist_ok=True)
joblib.dump(final_df, "models/preprocessed_timeseries.pkl")
# Out:
# ['models/preprocessed_timeseries.pkl']
